# %% [markdown]
# ## Download taxi trip data

# %% [markdown]
# Open `.csv` file and download all trip data links (approximately 300GB).

# %%
import os
import requests

def download_file(url, folder):
    """Download online file and save it.

    Arguments:
        url {String} -- Url to download
        folder {String} -- Folder where file will be saved
    """
    
    # The last part of the url is the file name
    file_name = f'{url.split("/")[-1]}'

    output_file = "{}/{}".format(folder, file_name)
    
    if os.path.exists(output_file):
         print("File  '{}' already exists.".format(output_file))
    else:
        # Download if file does not exist
        print(f"Downloading {url}...")
        r = requests.get(url, allow_redirects=True)
        print(f"Saving '{output_file}'")
        open(output_file, "wb").write(r.content)

# %%
import pandas as pd

# Trip links source        
path_trip_list = "c:/Users/LocalAdmin/OneDrive/leap_forward/street_network_server/tenv/data/in/trip_data/nyc_tripdata.csv"

# Local to save
target_path = "o:/phd/nyc_trips"

# Loading trip data csv (year, month, type[green, yellow, fhv], link)
df = pd.read_csv(path_trip_list)

# Filter trips from year
select_year = 2011
filter_links = df["year"]==select_year
links = df[filter_links]["link"]

# Download all
links = df["link"]

# Donwload all links
for link in links:
    download_file(link, target_path)
# Out:
# File  'o:/phd/nyc_trips/yellow_tripdata_2018-01.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2018-01.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2018-01.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2018-02.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2018-02.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2018-02.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2018-03.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2018-03.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2018-03.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2018-04.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2018-04.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2018-04.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2018-05.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2018-05.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2018-05.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2018-06.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2018-06.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2018-06.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2018-07.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2018-07.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2018-07.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2018-08.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2018-08.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2018-08.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2018-09.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2018-09.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2018-09.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2018-10.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2018-10.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2018-10.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2018-11.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2018-11.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2018-11.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2018-12.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2018-12.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2018-12.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2017-01.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2017-01.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2017-01.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2017-02.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2017-02.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2017-02.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2017-03.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2017-03.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2017-03.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2017-04.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2017-04.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2017-04.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2017-05.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2017-05.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2017-05.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2017-06.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2017-06.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2017-06.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2017-07.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2017-07.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2017-07.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2017-08.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2017-09.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2017-08.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2017-09.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2017-09.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2017-09.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2017-10.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2017-10.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2017-10.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2017-11.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2017-11.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2017-11.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2017-12.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2017-12.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2017-12.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2016-01.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2016-01.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2016-01.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2016-02.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2016-02.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2016-02.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2016-03.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2016-03.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2016-03.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2016-04.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2016-04.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2016-04.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2016-05.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2016-05.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2016-05.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2016-06.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2016-06.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2016-06.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2016-07.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2016-07.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2016-07.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2016-08.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2016-08.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2016-08.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2016-09.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2016-09.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2016-09.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2016-10.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2016-10.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2016-10.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2016-11.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2016-11.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2016-11.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2016-12.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2016-12.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2016-12.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2015-01.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2015-01.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2015-01.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2015-02.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2015-02.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2015-02.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2015-03.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2015-03.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2015-03.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2015-04.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2015-04.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2015-04.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2015-05.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2015-05.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2015-05.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2015-06.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2015-06.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2015-06.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2015-07.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2015-07.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2015-07.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2015-08.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2015-08.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2015-08.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2015-09.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2015-09.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2015-09.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2015-10.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2015-10.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2015-10.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2015-11.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2015-11.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2015-11.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2015-12.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2015-12.csv' already exists.
# File  'o:/phd/nyc_trips/fhv_tripdata_2015-12.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2014-01.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2014-01.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2014-02.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2014-02.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2014-03.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2014-03.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2014-04.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2014-04.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2014-05.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2014-05.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2014-06.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2014-06.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2014-07.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2014-07.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2014-08.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2014-08.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2014-09.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2014-09.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2014-10.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2014-10.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2014-11.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2014-11.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2014-12.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2014-12.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2013-01.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2013-02.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2013-03.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2013-04.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2013-05.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2013-06.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2013-07.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2013-08.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2013-08.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2013-09.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2013-09.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2013-10.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2013-10.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2013-11.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2013-11.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2013-12.csv' already exists.
# File  'o:/phd/nyc_trips/green_tripdata_2013-12.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2012-01.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2012-02.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2012-03.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2012-04.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2012-05.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2012-06.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2012-07.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2012-08.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2012-09.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2012-10.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2012-11.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2012-12.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2011-01.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2011-02.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2011-03.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2011-04.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2011-05.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2011-06.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2011-07.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2011-08.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2011-09.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2011-10.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2011-11.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2011-12.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2010-01.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2010-02.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2010-03.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2010-04.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2010-05.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2010-06.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2010-07.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2010-08.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2010-09.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2010-10.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2010-11.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2010-12.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2009-01.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2009-02.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2009-03.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2009-04.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2009-05.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2009-06.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2009-07.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2009-08.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2009-09.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2009-10.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2009-11.csv' already exists.
# File  'o:/phd/nyc_trips/yellow_tripdata_2009-12.csv' already exists.
# File  'o:/phd/nyc_trips/uber-raw-data-apr14.csv' already exists.
# File  'o:/phd/nyc_trips/uber-raw-data-may14.csv' already exists.
# File  'o:/phd/nyc_trips/uber-raw-data-jun14.csv' already exists.
# File  'o:/phd/nyc_trips/uber-raw-data-jul14.csv' already exists.
# File  'o:/phd/nyc_trips/uber-raw-data-aug14.csv' already exists.
# File  'o:/phd/nyc_trips/uber-raw-data-sep14.csv' already exists.

# %% [markdown]
# ## Generate date excerpts

# %%
from datetime import datetime, timedelta
import pandas as pd
import numpy as np
from collections import defaultdict
import json
import pprint

# Select time windows for days of an year
def get_dates(start, weeks, h1, m1, s1, h2, m2, s2):
    
    start_dt = datetime.strptime(start, "%Y-%m-%d %H:%M:%S")

    dates_year = start_dt+pd.to_timedelta(np.arange(weeks), 'W')

    for i in range(1,13):
        days_month = dates_year[dates_year.month==i]
        for d in days_month:
            yield (
                (d.year, d.month, d.day),
                d+timedelta(hours=h1, minutes=m1, seconds=s1),
                d+timedelta(hours=h2, minutes=m2, seconds=s2)
            )


start = "2011-01-04 00:00:00"
n_weeks = 52
#path = "O:/phd/nyc_trips/raw/"
path = ""
day_tw = defaultdict(list)
for (y,m,d), earliest, latest in get_dates(start, n_weeks, 0, 0, 0, 23, 59, 59):
    data_path = f"{path}yellow_tripdata_{y}-{m:02}.csv"
    day_tw[data_path].append((str(earliest), str(latest)))

pprint.pprint(day_tw)

# Version to paste in json file
pprint.pprint(json.dumps(day_tw))
# Out:
# defaultdict(<class 'list'>,
#             {'yellow_tripdata_2011-01.csv': [('2011-01-04 00:00:00',
#                                               '2011-01-04 23:59:59'),
#                                              ('2011-01-11 00:00:00',
#                                               '2011-01-11 23:59:59'),
#                                              ('2011-01-18 00:00:00',
#                                               '2011-01-18 23:59:59'),
#                                              ('2011-01-25 00:00:00',
#                                               '2011-01-25 23:59:59')],
#              'yellow_tripdata_2011-02.csv': [('2011-02-01 00:00:00',
#                                               '2011-02-01 23:59:59'),
#                                              ('2011-02-08 00:00:00',
#                                               '2011-02-08 23:59:59'),
#                                              ('2011-02-15 00:00:00',
#                                               '2011-02-15 23:59:59'),
#                                              ('2011-02-22 00:00:00',
#                                               '2011-02-22 23:59:59')],
#              'yellow_tripdata_2011-03.csv': [('2011-03-01 00:00:00',
#                                               '2011-03-01 23:59:59'),
#                                              ('2011-03-08 00:00:00',
#                                               '2011-03-08 23:59:59'),
#                                              ('2011-03-15 00:00:00',
#                                               '2011-03-15 23:59:59'),
#                                              ('2011-03-22 00:00:00',
#                                               '2011-03-22 23:59:59'),
#                                              ('2011-03-29 00:00:00',
#                                               '2011-03-29 23:59:59')],
#              'yellow_tripdata_2011-04.csv': [('2011-04-05 00:00:00',
#                                               '2011-04-05 23:59:59'),
#                                              ('2011-04-12 00:00:00',
#                                               '2011-04-12 23:59:59'),
#                                              ('2011-04-19 00:00:00',
#                                               '2011-04-19 23:59:59'),
#                                              ('2011-04-26 00:00:00',
#                                               '2011-04-26 23:59:59')],
#              'yellow_tripdata_2011-05.csv': [('2011-05-03 00:00:00',
#                                               '2011-05-03 23:59:59'),
#                                              ('2011-05-10 00:00:00',
#                                               '2011-05-10 23:59:59'),
#                                              ('2011-05-17 00:00:00',
#                                               '2011-05-17 23:59:59'),
#                                              ('2011-05-24 00:00:00',
#                                               '2011-05-24 23:59:59'),
#                                              ('2011-05-31 00:00:00',
#                                               '2011-05-31 23:59:59')],
#              'yellow_tripdata_2011-06.csv': [('2011-06-07 00:00:00',
#                                               '2011-06-07 23:59:59'),
#                                              ('2011-06-14 00:00:00',
#                                               '2011-06-14 23:59:59'),
#                                              ('2011-06-21 00:00:00',
#                                               '2011-06-21 23:59:59'),
#                                              ('2011-06-28 00:00:00',
#                                               '2011-06-28 23:59:59')],
#              'yellow_tripdata_2011-07.csv': [('2011-07-05 00:00:00',
#                                               '2011-07-05 23:59:59'),
#                                              ('2011-07-12 00:00:00',
#                                               '2011-07-12 23:59:59'),
#                                              ('2011-07-19 00:00:00',
#                                               '2011-07-19 23:59:59'),
#                                              ('2011-07-26 00:00:00',
#                                               '2011-07-26 23:59:59')],
#              'yellow_tripdata_2011-08.csv': [('2011-08-02 00:00:00',
#                                               '2011-08-02 23:59:59'),
#                                              ('2011-08-09 00:00:00',
#                                               '2011-08-09 23:59:59'),
#                                              ('2011-08-16 00:00:00',
#                                               '2011-08-16 23:59:59'),
#                                              ('2011-08-23 00:00:00',
#                                               '2011-08-23 23:59:59'),
#                                              ('2011-08-30 00:00:00',
#                                               '2011-08-30 23:59:59')],
#              'yellow_tripdata_2011-09.csv': [('2011-09-06 00:00:00',
#                                               '2011-09-06 23:59:59'),
#                                              ('2011-09-13 00:00:00',
#                                               '2011-09-13 23:59:59'),
#                                              ('2011-09-20 00:00:00',
#                                               '2011-09-20 23:59:59'),
#                                              ('2011-09-27 00:00:00',
#                                               '2011-09-27 23:59:59')],
#              'yellow_tripdata_2011-10.csv': [('2011-10-04 00:00:00',
#                                               '2011-10-04 23:59:59'),
#                                              ('2011-10-11 00:00:00',
#                                               '2011-10-11 23:59:59'),
#                                              ('2011-10-18 00:00:00',
#                                               '2011-10-18 23:59:59'),
#                                              ('2011-10-25 00:00:00',
#                                               '2011-10-25 23:59:59')],
#              'yellow_tripdata_2011-11.csv': [('2011-11-01 00:00:00',
#                                               '2011-11-01 23:59:59'),
#                                              ('2011-11-08 00:00:00',
#                                               '2011-11-08 23:59:59'),
#                                              ('2011-11-15 00:00:00',
#                                               '2011-11-15 23:59:59'),
#                                              ('2011-11-22 00:00:00',
#                                               '2011-11-22 23:59:59'),
#                                              ('2011-11-29 00:00:00',
#                                               '2011-11-29 23:59:59')],
#              'yellow_tripdata_2011-12.csv': [('2011-12-06 00:00:00',
#                                               '2011-12-06 23:59:59'),
#                                              ('2011-12-13 00:00:00',
#                                               '2011-12-13 23:59:59'),
#                                              ('2011-12-20 00:00:00',
#                                               '2011-12-20 23:59:59'),
#                                              ('2011-12-27 00:00:00',
#                                               '2011-12-27 23:59:59')]})
# ('{"yellow_tripdata_2011-01.csv": [["2011-01-04 00:00:00", "2011-01-04 '
#  '23:59:59"], ["2011-01-11 00:00:00", "2011-01-11 23:59:59"], ["2011-01-18 '
#  '00:00:00", "2011-01-18 23:59:59"], ["2011-01-25 00:00:00", "2011-01-25 '
#  '23:59:59"]], "yellow_tripdata_2011-02.csv": [["2011-02-01 00:00:00", '
#  '"2011-02-01 23:59:59"], ["2011-02-08 00:00:00", "2011-02-08 23:59:59"], '
#  '["2011-02-15 00:00:00", "2011-02-15 23:59:59"], ["2011-02-22 00:00:00", '
#  '"2011-02-22 23:59:59"]], "yellow_tripdata_2011-03.csv": [["2011-03-01 '
#  '00:00:00", "2011-03-01 23:59:59"], ["2011-03-08 00:00:00", "2011-03-08 '
#  '23:59:59"], ["2011-03-15 00:00:00", "2011-03-15 23:59:59"], ["2011-03-22 '
#  '00:00:00", "2011-03-22 23:59:59"], ["2011-03-29 00:00:00", "2011-03-29 '
#  '23:59:59"]], "yellow_tripdata_2011-04.csv": [["2011-04-05 00:00:00", '
#  '"2011-04-05 23:59:59"], ["2011-04-12 00:00:00", "2011-04-12 23:59:59"], '
#  '["2011-04-19 00:00:00", "2011-04-19 23:59:59"], ["2011-04-26 00:00:00", '
#  '"2011-04-26 23:59:59"]], "yellow_tripdata_2011-05.csv": [["2011-05-03 '
#  '00:00:00", "2011-05-03 23:59:59"], ["2011-05-10 00:00:00", "2011-05-10 '
#  '23:59:59"], ["2011-05-17 00:00:00", "2011-05-17 23:59:59"], ["2011-05-24 '
#  '00:00:00", "2011-05-24 23:59:59"], ["2011-05-31 00:00:00", "2011-05-31 '
#  '23:59:59"]], "yellow_tripdata_2011-06.csv": [["2011-06-07 00:00:00", '
#  '"2011-06-07 23:59:59"], ["2011-06-14 00:00:00", "2011-06-14 23:59:59"], '
#  '["2011-06-21 00:00:00", "2011-06-21 23:59:59"], ["2011-06-28 00:00:00", '
#  '"2011-06-28 23:59:59"]], "yellow_tripdata_2011-07.csv": [["2011-07-05 '
#  '00:00:00", "2011-07-05 23:59:59"], ["2011-07-12 00:00:00", "2011-07-12 '
#  '23:59:59"], ["2011-07-19 00:00:00", "2011-07-19 23:59:59"], ["2011-07-26 '
#  '00:00:00", "2011-07-26 23:59:59"]], "yellow_tripdata_2011-08.csv": '
#  '[["2011-08-02 00:00:00", "2011-08-02 23:59:59"], ["2011-08-09 00:00:00", '
#  '"2011-08-09 23:59:59"], ["2011-08-16 00:00:00", "2011-08-16 23:59:59"], '
#  '["2011-08-23 00:00:00", "2011-08-23 23:59:59"], ["2011-08-30 00:00:00", '
#  '"2011-08-30 23:59:59"]], "yellow_tripdata_2011-09.csv": [["2011-09-06 '
#  '00:00:00", "2011-09-06 23:59:59"], ["2011-09-13 00:00:00", "2011-09-13 '
#  '23:59:59"], ["2011-09-20 00:00:00", "2011-09-20 23:59:59"], ["2011-09-27 '
#  '00:00:00", "2011-09-27 23:59:59"]], "yellow_tripdata_2011-10.csv": '
#  '[["2011-10-04 00:00:00", "2011-10-04 23:59:59"], ["2011-10-11 00:00:00", '
#  '"2011-10-11 23:59:59"], ["2011-10-18 00:00:00", "2011-10-18 23:59:59"], '
#  '["2011-10-25 00:00:00", "2011-10-25 23:59:59"]], '
#  '"yellow_tripdata_2011-11.csv": [["2011-11-01 00:00:00", "2011-11-01 '
#  '23:59:59"], ["2011-11-08 00:00:00", "2011-11-08 23:59:59"], ["2011-11-15 '
#  '00:00:00", "2011-11-15 23:59:59"], ["2011-11-22 00:00:00", "2011-11-22 '
#  '23:59:59"], ["2011-11-29 00:00:00", "2011-11-29 23:59:59"]], '
#  '"yellow_tripdata_2011-12.csv": [["2011-12-06 00:00:00", "2011-12-06 '
#  '23:59:59"], ["2011-12-13 00:00:00", "2011-12-13 23:59:59"], ["2011-12-20 '
#  '00:00:00", "2011-12-20 23:59:59"], ["2011-12-27 00:00:00", "2011-12-27 '
#  '23:59:59"]]}')
